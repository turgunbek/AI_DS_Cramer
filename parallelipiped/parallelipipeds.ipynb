# %%
import json
import numpy as np

# %%
f = open('parallelepipeds.json')
data = json.load(f)

# %%
def get_characteristics_of_parallelipiped(dict_abc: dict) -> tuple[float]:
    a, b, c = map(float, [dict_abc['a'], dict_abc['b'], dict_abc['c']])
    diag = np.sqrt(a**2 + b**2 + c**2)
    volume = a * b * c
    surface_area = 2 * (a*b + b*c + c*a)
    alpha = np.rad2deg(np.arccos(a / diag))
    beta = np.rad2deg(np.arccos(b / diag))
    gamma = np.rad2deg(np.arccos(c / diag))
    radius_described_sphere = 0.5 * diag
    volume_described_sphere = 4/3 * np.pi * radius_described_sphere**3
    result = {
        'diag': diag,
        'volume': volume,
        'surface_area': surface_area,
        'alpha': alpha,
        'beta': beta,
        'gamma': gamma,
        'radius_described_sphere': radius_described_sphere,
        'volume_described_sphere': volume_described_sphere
             }
    return result

# %%
average_values = dict()

result_dict = dict()
for k, v in data.items():
    params = get_characteristics_of_parallelipiped(v)
    
    for param_name, param_val in params.items():
        avg_name = 'avg_' + param_name
        if avg_name not in average_values:
            average_values[avg_name] = param_val
        else:
            average_values[avg_name] += param_val
        params[param_name] = str(param_val)
    
    result_dict[k] = params

n = len(average_values)
for k, v in average_values.items():
    average_values[k] = v / n

# %%
result_dict
# Out:
# {'figure_1': {'diag': '6.4031242374328485',
#   'volume': '12.0',
#   'surface_area': '40.0',
#   'alpha': '71.79923973546668',
#   'beta': '81.01512306831432',
#   'gamma': '20.439317573258254',
#   'radius_described_sphere': '3.2015621187164243',
#   'volume_described_sphere': '137.45938843966883'},
#  'figure_2': {'diag': '23.49468024894146',
#   'volume': '2240.0',
#   'surface_area': '1048.0',
#   'alpha': '47.07775513424629',
#   'beta': '64.80956295820124',
#   'gamma': '53.42463981140845',
#   'radius_described_sphere': '11.74734012447073',
#   'volume_described_sphere': '6790.585767903444'},
#  'figure_3': {'diag': '28.337254630609507',
#   'volume': '3249.0',
#   'surface_area': '1406.0',
#   'alpha': '47.8946854114486',
#   'beta': '71.48196751869054',
#   'gamma': '47.8946854114486',
#   'radius_described_sphere': '14.168627315304754',
#   'volume_described_sphere': '11914.393518208703'},
#  'figure_4': {'diag': '25.03996805109783',
#   'volume': '2873.0',
#   'surface_area': '1222.0',
#   'alpha': '58.723407378672526',
#   'beta': '47.24111549512873',
#   'gamma': '58.723407378672526',
#   'radius_described_sphere': '12.519984025548915',
#   'volume_described_sphere': '8220.532176084742'},
#  'figure_5': {'diag': '16.55294535724685',
#   'volume': '144.0',
#   'surface_area': '210.0',
#   'alpha': '79.55820182827425',
#   'beta': '14.851062468857855',
#   'gamma': '79.55820182827425',
#   'radius_described_sphere': '8.276472678623424',
#   'volume_described_sphere': '2374.785926518399'},
#  'figure_6': {'diag': '20.445048300260872',
#   'volume': '1260.0',
#   'surface_area': '738.0',
#   'alpha': '54.05989695435807',
#   'beta': '69.9779842995373',
#   'gamma': '42.80471223274384',
#   'radius_described_sphere': '10.222524150130436',
#   'volume_described_sphere': '4474.690943453033'},
#  'figure_7': {'diag': '16.431676725154983',
#   'volume': '770.0',
#   'surface_area': '514.0',
#   'alpha': '64.78561598077519',
#   'beta': '52.51305687955973',
#   'gamma': '47.97624326398288',
#   'radius_described_sphere': '8.215838362577491',
#   'volume_described_sphere': '2322.9735698659174'},
#  'figure_8': {'diag': '13.152946437965905',
#   'volume': '264.0',
#   'surface_area': '268.0',
#   'alpha': '33.247036563878666',
#   'beta': '62.85966063867525',
#   'gamma': '72.29510986341144',
#   'radius_described_sphere': '6.576473218982953',
#   'volume_described_sphere': '1191.427930524209'},
#  'figure_9': {'diag': '21.18962010041709',
#   'volume': '396.0',
#   'surface_area': '512.0',
#   'alpha': '58.72661816113163',
#   'beta': '84.58402804865804',
#   'gamma': '31.845655897371735',
#   'radius_described_sphere': '10.594810050208546',
#   'volume_described_sphere': '4981.5917538471995'},
#  'figure_10': {'diag': '23.065125189341593',
#   'volume': '1728.0',
#   'surface_area': '912.0',
#   'alpha': '38.70288051835593',
#   'beta': '69.70559965222992',
#   'gamma': '58.649905284535166',
#   'radius_described_sphere': '11.532562594670797',
#   'volume_described_sphere': '6424.895535941514'},
#  'figure_11': {'diag': '25.03996805109783',
#   'volume': '2873.0',
#   'surface_area': '1222.0',
#   'alpha': '58.723407378672526',
#   'beta': '58.723407378672526',
#   'gamma': '47.24111549512873',
#   'radius_described_sphere': '12.519984025548915',
#   'volume_described_sphere': '8220.532176084742'},
#  'figure_12': {'diag': '13.638181696985855',
#   'volume': '52.0',
#   'surface_area': '138.0',
#   'alpha': '72.94471991060612',
#   'beta': '17.597047550204604',
#   'gamma': '85.79509602520164',
#   'radius_described_sphere': '6.819090848492928',
#   'volume_described_sphere': '1328.2139542547795'},
#  'figure_13': {'diag': '20.83266665599966',
#   'volume': '1716.0',
#   'surface_area': '862.0',
#   'alpha': '51.38970812096877',
#   'beta': '58.128437797906756',
#   'gamma': '54.829015088512',
#   'radius_described_sphere': '10.41633332799983',
#   'volume_described_sphere': '4734.054099031555'},
#  'figure_14': {'diag': '16.673332000533065',
#   'volume': '210.0',
#   'surface_area': '298.0',
#   'alpha': '65.17601223718187',
#   'beta': '83.1106659668402',
#   'gamma': '25.889184557134524',
#   'radius_described_sphere': '8.336666000266533',
#   'volume_described_sphere': '2426.9778693332064'},
#  'figure_15': {'diag': '25.67099530598687',
#   'volume': '969.0',
#   'surface_area': '862.0',
#   'alpha': '48.53013962909259',
#   'beta': '83.28888473063067',
#   'gamma': '42.25709023783597',
#   'radius_described_sphere': '12.835497652993435',
#   'volume_described_sphere': '8857.8178272883'},
#  'figure_16': {'diag': '17.291616465790582',
#   'volume': '819.0',
#   'surface_area': '542.0',
#   'alpha': '58.63531479775195',
#   'beta': '41.252641273036666',
#   'gamma': '66.1201237462351',
#   'radius_described_sphere': '8.645808232895291',
#   'volume_described_sphere': '2707.106893671396'},
#  'figure_17': {'diag': '20.223748416156685',
#   'volume': '324.0',
#   'surface_area': '432.0',
#   'alpha': '63.57529469692526',
#   'beta': '27.12138475569016',
#   'gamma': '84.32453535228755',
#   'radius_described_sphere': '10.111874208078342',
#   'volume_described_sphere': '4330.954132661439'},
#  'figure_18': {'diag': '17.46424919657298',
#   'volume': '780.0',
#   'surface_area': '536.0',
#   'alpha': '55.068385014185104',
#   'beta': '69.90614339602168',
#   'gamma': '41.894312564871',
#   'radius_described_sphere': '8.73212459828649',
#   'volume_described_sphere': '2788.999146301101'},
#  'figure_19': {'diag': '14.247806848775006',
#   'volume': '99.0',
#   'surface_area': '238.0',
#   'alpha': '39.461786321072275',
#   'beta': '50.82610444960803',
#   'gamma': '85.97531566954986',
#   'radius_described_sphere': '7.123903424387503',
#   'volume_described_sphere': '1514.4072468588688'},
#  'figure_20': {'diag': '21.18962010041709',
#   'volume': '816.0',
#   'surface_area': '640.0',
#   'alpha': '55.506341868768544',
#   'beta': '79.11889098196662',
#   'gamma': '36.65165688691556',
#   'radius_described_sphere': '10.594810050208546',
#   'volume_described_sphere': '4981.5917538471995'},
#  'figure_21': {'diag': '15.033296378372908',
#   'volume': '108.0',
#   'surface_area': '258.0',
#   'alpha': '86.18592516570965',
#   'beta': '37.038767555809535',
#   'gamma': '53.22521901453807',
#   'radius_described_sphere': '7.516648189186454',
#   'volume_described_sphere': '1778.9399203844612'},
#  'figure_22': {'diag': '17.08800749063506',
#   'volume': '288.0',
#   'surface_area': '384.0',
#   'alpha': '83.27863066063054',
#   'beta': '45.39244912064032',
#   'gamma': '45.39244912064032',
#   'radius_described_sphere': '8.54400374531753',
#   'volume_described_sphere': '2612.599861457234'},
#  'figure_23': {'diag': '22.22611077089287',
#   'volume': '234.0',
#   'surface_area': '530.0',
#   'alpha': '54.204240085292916',
#   'beta': '87.42127049154782',
#   'gamma': '35.91791199615899',
#   'radius_described_sphere': '11.113055385446435',
#   'volume_described_sphere': '5748.956806660125'},
#  'figure_24': {'diag': '25.475478405713993',
#   'volume': '2700.0',
#   'surface_area': '1200.0',
#   'alpha': '53.9279946610351',
#   'beta': '45.04414160414846',
#   'gamma': '66.88771462145436',
#   'radius_described_sphere': '12.737739202856996',
#   'volume_described_sphere': '8656.965116357273'},
#  'figure_25': {'diag': '1.7320508075688772',
#   'volume': '1.0',
#   'surface_area': '6.0',
#   'alpha': '54.735610317245346',
#   'beta': '54.735610317245346',
#   'gamma': '54.735610317245346',
#   'radius_described_sphere': '0.8660254037844386',
#   'volume_described_sphere': '2.720699046351326'},
#  'figure_26': {'diag': '24.779023386727733',
#   'volume': '306.0',
#   'surface_area': '682.0',
#   'alpha': '43.41282292446423',
#   'beta': '87.6871024080138',
#   'gamma': '46.680644698208944',
#   'radius_described_sphere': '12.389511693363866',
#   'volume_described_sphere': '7966.199511768722'},
#  'figure_27': {'diag': '22.494443758403985',
#   'volume': '1872.0',
#   'surface_area': '938.0',
#   'alpha': '66.41564478548749',
#   'beta': '44.66029374142849',
#   'gamma': '54.69558636083866',
#   'radius_described_sphere': '11.247221879201993',
#   'volume_described_sphere': '5959.699984090552'},
#  'figure_28': {'diag': '32.341923257592455',
#   'volume': '6498.0',
#   'surface_area': '2090.0',
#   'alpha': '54.02212569750698',
#   'beta': '56.1822397744379',
#   'gamma': '54.02212569750698',
#   'radius_described_sphere': '16.170961628796228',
#   'volume_described_sphere': '17713.164223405347'},
#  'figure_29': {'diag': '4.242640687119285',
#   'volume': '4.0',
#   'surface_area': '18.0',
#   'alpha': '19.471220634490674',
#   'beta': '76.3669777746336',
#   'gamma': '76.3669777746336',
#   'radius_described_sphere': '2.1213203435596424',
#   'volume_described_sphere': '39.98594644342528'},
#  'figure_30': {'diag': '20.615528128088304',
#   'volume': '960.0',
#   'surface_area': '664.0',
#   'alpha': '54.40264031417013',
#   'beta': '75.96375653207353',
#   'gamma': '39.0938588862295',
#   'radius_described_sphere': '10.307764064044152',
#   'volume_described_sphere': '4587.562746626213'},
#  'figure_31': {'diag': '22.22611077089287',
#   'volume': '1950.0',
#   'surface_area': '950.0',
#   'alpha': '47.55501980101057',
#   'beta': '63.26136712927481',
#   'gamma': '54.204240085292916',
#   'radius_described_sphere': '11.113055385446435',
#   'volume_described_sphere': '5748.956806660125'},
#  'figure_32': {'diag': '29.546573405388315',
#   'volume': '4864.0',
#   'surface_area': '1728.0',
#   'alpha': '49.9801795006935',
#   'beta': '57.212967497008826',
#   'gamma': '57.212967497008826',
#   'radius_described_sphere': '14.773286702694158',
#   'volume_described_sphere': '13505.789851596886'},
#  'figure_33': {'diag': '25.98076211353316',
#   'volume': '1615.0',
#   'surface_area': '1006.0',
#   'alpha': '43.00364267343271',
#   'beta': '78.90419671686361',
#   'gamma': '49.13111037306979',
#   'radius_described_sphere': '12.99038105676658',
#   'volume_described_sphere': '9182.359281435727'},
#  'figure_34': {'diag': '10.816653826391969',
#   'volume': '40.0',
#   'surface_area': '108.0',
#   'alpha': '68.29670863577394',
#   'beta': '84.6954285609024',
#   'gamma': '22.406871204937463',
#   'radius_described_sphere': '5.408326913195984',
#   'volume_described_sphere': '662.6396438496304'},
#  'figure_35': {'diag': '20.223748416156685',
#   'volume': '1584.0',
#   'surface_area': '816.0',
#   'alpha': '57.049450730825995',
#   'beta': '53.604062727820384',
#   'gamma': '53.604062727820384',
#   'radius_described_sphere': '10.111874208078342',
#   'volume_described_sphere': '4330.954132661439'},
#  'figure_36': {'diag': '23.727621035409346',
#   'volume': '1881.0',
#   'surface_area': '958.0',
#   'alpha': '36.797784933359544',
#   'beta': '67.70937441785671',
#   'gamma': '62.380686941621434',
#   'radius_described_sphere': '11.863810517704673',
#   'volume_described_sphere': '6994.573120286435'},
#  'figure_37': {'diag': '13.152946437965905',
#   'volume': '120.0',
#   'surface_area': '188.0',
#   'alpha': '67.65746175217022',
#   'beta': '24.16881343581011',
#   'gamma': '81.2538377374448',
#   'radius_described_sphere': '6.576473218982953',
#   'volume_described_sphere': '1191.427930524209'},
#  'figure_38': {'diag': '17.4928556845359',
#   'volume': '968.0',
#   'surface_area': '594.0',
#   'alpha': '51.03628194073718',
#   'beta': '51.03628194073718',
#   'gamma': '62.78507729277375',
#   'radius_described_sphere': '8.74642784226795',
#   'volume_described_sphere': '2802.7267723510654'},
#  'figure_39': {'diag': '20.322401432901575',
#   'volume': '1560.0',
#   'surface_area': '812.0',
#   'alpha': '53.80882292265681',
#   'beta': '50.231428151926714',
#   'gamma': '60.5234150284271',
#   'radius_described_sphere': '10.161200716450788',
#   'volume_described_sphere': '4394.644001591048'},
#  'figure_40': {'diag': '20.09975124224178',
#   'volume': '576.0',
#   'surface_area': '496.0',
#   'alpha': '66.54586268400392',
#   'beta': '26.42296509240818',
#   'gamma': '78.52107728102163',
#   'radius_described_sphere': '10.04987562112089',
#   'volume_described_sphere': '4251.778876668345'},
#  'figure_41': {'diag': '20.024984394500787',
#   'volume': '588.0',
#   'surface_area': '560.0',
#   'alpha': '81.38391884989043',
#   'beta': '45.6430240868888',
#   'gamma': '45.6430240868888',
#   'radius_described_sphere': '10.012492197250394',
#   'volume_described_sphere': '4204.507981444598'},
#  'figure_42': {'diag': '18.05547008526779',
#   'volume': '882.0',
#   'surface_area': '574.0',
#   'alpha': '67.18890187827549',
#   'beta': '39.15975081841091',
#   'gamma': '60.10157575588988',
#   'radius_described_sphere': '9.027735042633894',
#   'volume_described_sphere': '3081.9459816163244'},
#  'figure_43': {'diag': '19.44222209522358',
#   'volume': '76.0',
#   'surface_area': '198.0',
#   'alpha': '78.12730744153491',
#   'beta': '87.05172217230157',
#   'gamma': '12.2436678354611',
#   'radius_described_sphere': '9.72111104761179',
#   'volume_described_sphere': '3848.01115254038'},
#  'figure_44': {'diag': '8.660254037844387',
#   'volume': '35.0',
#   'surface_area': '94.0',
#   'alpha': '54.735610317245346',
#   'beta': '83.36926223192135',
#   'gamma': '36.07076865079636',
#   'radius_described_sphere': '4.330127018922194',
#   'volume_described_sphere': '340.0873807939159'},
#  'figure_45': {'diag': '29.223278392404914',
#   'volume': '4446.0',
#   'surface_area': '1646.0',
#   'alpha': '63.58620392125943',
#   'beta': '51.97921348078494',
#   'gamma': '49.44583487028147',
#   'radius_described_sphere': '14.611639196202457',
#   'volume_described_sphere': '13067.286958587645'},
#  'figure_46': {'diag': '15.132745950421556',
#   'volume': '504.0',
#   'surface_area': '396.0',
#   'alpha': '37.53490600791177',
#   'beta': '62.44673516507556',
#   'gamma': '66.64099359025357',
#   'radius_described_sphere': '7.566372975210778',
#   'volume_described_sphere': '1814.478580497513'},
#  'figure_47': {'diag': '21.633307652783937',
#   'volume': '896.0',
#   'surface_area': '688.0',
#   'alpha': '49.672915655670266',
#   'beta': '42.302624878481225',
#   'gamma': '79.34469394919681',
#   'radius_described_sphere': '10.816653826391969',
#   'volume_described_sphere': '5301.117150797043'},
#  'figure_48': {'diag': '15.165750888103101',
#   'volume': '630.0',
#   'surface_area': '446.0',
#   'alpha': '53.59832434312973',
#   'beta': '48.74735872696335',
#   'gamma': '62.51177372615187',
#   'radius_described_sphere': '7.582875444051551',
#   'volume_described_sphere': '1826.3767770891072'},
#  'figure_49': {'diag': '23.021728866442675',
#   'volume': '1680.0',
#   'surface_area': '914.0',
#   'alpha': '49.340800848418624',
#   'beta': '72.29834552210988',
#   'gamma': '45.97313433504853',
#   'radius_described_sphere': '11.510864433221338',
#   'volume_described_sphere': '6388.698994711459'},
#  'figure_50': {'diag': '21.0',
#   'volume': '608.0',
#   'surface_area': '520.0',
#   'alpha': '67.60731219459836',
#   'beta': '79.01942457238785',
#   'gamma': '25.208765296758365',
#   'radius_described_sphere': '10.5',
#   'volume_described_sphere': '4849.048260815845'},
#  'figure_51': {'diag': '24.899799195977465',
#   'volume': '2520.0',
#   'surface_area': '1144.0',
#   'alpha': '66.32115498996998',
#   'beta': '55.78821191646129',
#   'gamma': '43.7057841444535',
#   'radius_described_sphere': '12.449899597988733',
#   'volume_described_sphere': '8083.25271042753'},
#  'figure_52': {'diag': '19.0',
#   'volume': '108.0',
#   'surface_area': '264.0',
#   'alpha': '86.98303869018402',
#   'beta': '71.59151982941417',
#   'gamma': '18.671718064007887',
#   'radius_described_sphere': '9.5',
#   'volume_described_sphere': '3591.3640018287315'},
#  'figure_53': {'diag': '13.92838827718412',
#   'volume': '156.0',
#   'surface_area': '206.0',
#   'alpha': '21.037511025421825',
#   'beta': '77.56174101153906',
#   'gamma': '73.3106029686627',
#   'radius_described_sphere': '6.96419413859206',
#   'volume_described_sphere': '1414.8200873103128'},
#  'figure_54': {'diag': '18.681541692269406',
#   'volume': '504.0',
#   'surface_area': '492.0',
#   'alpha': '80.75907014213428',
#   'beta': '50.03307625954864',
#   'gamma': '41.461325354457735',
#   'radius_described_sphere': '9.340770846134703',
#   'volume_described_sphere': '3413.789692369931'},
#  'figure_55': {'diag': '16.881943016134134',
#   'volume': '160.0',
#   'surface_area': '244.0',
#   'alpha': '18.60183317969283',
#   'beta': '83.19620279628194',
#   'gamma': '72.77202476935234',
#   'radius_described_sphere': '8.440971508067067',
#   'volume_described_sphere': '2519.2189374959044'},
#  'figure_56': {'diag': '18.384776310850235',
#   'volume': '840.0',
#   'surface_area': '562.0',
#   'alpha': '64.20562971609478',
#   'beta': '67.61986494804043',
#   'gamma': '35.32429987761792',
#   'radius_described_sphere': '9.192388155425117',
#   'volume_described_sphere': '3253.671271711309'},
#  'figure_57': {'diag': '17.72004514666935',
#   'volume': '336.0',
#   'surface_area': '362.0',
#   'alpha': '80.2528898707024',
#   'beta': '66.73197692888245',
#   'gamma': '25.453785781140812',
#   'radius_described_sphere': '8.860022573334675',
#   'volume_described_sphere': '2913.3528978955915'},
#  'figure_58': {'diag': '7.874007874011811',
#   'volume': '42.0',
#   'surface_area': '82.0',
#   'alpha': '27.25203367487419',
#   'beta': '75.2856464115665',
#   'gamma': '67.60433766996084',
#   'radius_described_sphere': '3.9370039370059056',
#   'volume_described_sphere': '255.6148946768048'},
#  'figure_59': {'diag': '19.026297590440446',
#   'volume': '660.0',
#   'surface_area': '538.0',
#   'alpha': '37.9653907911336',
#   'beta': '54.67967070414837',
#   'gamma': '77.86385631805953',
#   'radius_described_sphere': '9.513148795220223',
#   'volume_described_sphere': '3606.296896353499'},
#  'figure_60': {'diag': '21.400934559032695',
#   'volume': '1560.0',
#   'surface_area': '838.0',
#   'alpha': '68.04888062557634',
#   'beta': '45.50042527029914',
#   'gamma': '52.59464336859145',
#   'radius_described_sphere': '10.700467279516348',
#   'volume_described_sphere': '5132.120434350128'},
#  'figure_61': {'diag': '21.77154105707724',
#   'volume': '1496.0',
#   'surface_area': '822.0',
#   'alpha': '38.662830147534244',
#   'beta': '59.652267555852475',
#   'gamma': '68.44142844570928',
#   'radius_described_sphere': '10.88577052853862',
#   'volume_described_sphere': '5403.38776193715'},
#  'figure_62': {'diag': '19.87460691435179',
#   'volume': '765.0',
#   'surface_area': '566.0',
#   'alpha': '63.0740130268015',
#   'beta': '75.42913152053903',
#   'gamma': '31.200158266579802',
#   'radius_described_sphere': '9.937303457175895',
#   'volume_described_sphere': '4110.4963391115725'},
#  'figure_63': {'diag': '22.090722034374522',
#   'volume': '1440.0',
#   'surface_area': '808.0',
#   'alpha': '63.08432117378937',
#   'beta': '68.76813752414559',
#   'gamma': '35.43026277448198',
#   'radius_described_sphere': '11.045361017187261',
#   'volume_described_sphere': '5644.53740452906'},
#  'figure_64': {'diag': '21.748563170931547',
#   'volume': '1260.0',
#   'surface_area': '752.0',
#   'alpha': '34.142843285370326',
#   'beta': '62.62576577099123',
#   'gamma': '71.22453209055433',
#   'radius_described_sphere': '10.874281585465774',
#   'volume_described_sphere': '5386.297455383314'},
#  'figure_65': {'diag': '26.94438717061496',
#   'volume': '3458.0',
#   'surface_area': '1390.0',
#   'alpha': '61.15281017846856',
#   'beta': '58.69533141533954',
#   'gamma': '45.157840411561864',
#   'radius_described_sphere': '13.47219358530748',
#   'volume_described_sphere': '10242.442943672646'},
#  'figure_66': {'diag': '23.790754506740637',
#   'volume': '2142.0',
#   'surface_area': '1034.0',
#   'alpha': '53.95192304433122',
#   'beta': '44.39257873367787',
#   'gamma': '67.77168995699715',
#   'radius_described_sphere': '11.895377253370318',
#   'volume_described_sphere': '7050.554420543634'},
#  'figure_67': {'diag': '14.071247279470288',
#   'volume': '130.0',
#   'surface_area': '202.0',
#   'alpha': '22.501461477900534',
#   'beta': '69.18605182881443',
#   'gamma': '81.82866044342089',
#   'radius_described_sphere': '7.035623639735144',
#   'volume_described_sphere': '1458.802193640964'},
#  'figure_68': {'diag': '20.904544960366874',
#   'volume': '1008.0',
#   'surface_area': '652.0',
#   'alpha': '30.564554970816424',
#   'beta': '67.49947495345229',
#   'gamma': '70.43625417930163',
#   'radius_described_sphere': '10.452272480183437',
#   'volume_described_sphere': '4783.224641665518'},
#  'figure_69': {'diag': '13.674794331177344',
#   'volume': '117.0',
#   'surface_area': '174.0',
#   'alpha': '77.32727853351487',
#   'beta': '18.074454837604154',
#   'gamma': '77.32727853351487',
#   'radius_described_sphere': '6.837397165588672',
#   'volume_described_sphere': '1338.9397412838837'},
#  'figure_70': {'diag': '18.16590212458495',
#   'volume': '560.0',
#   'surface_area': '454.0',
#   'alpha': '74.02362679986724',
#   'beta': '28.264489545044984',
#   'gamma': '67.33531704245958',
#   'radius_described_sphere': '9.082951062292475',
#   'volume_described_sphere': '3138.842556323501'},
#  'figure_71': {'diag': '5.196152422706632',
#   'volume': '5.0',
#   'surface_area': '22.0',
#   'alpha': '15.79316904826397',
#   'beta': '78.90419671686361',
#   'gamma': '78.90419671686361',
#   'radius_described_sphere': '2.598076211353316',
#   'volume_described_sphere': '73.45887425148582'},
#  'figure_72': {'diag': '26.90724809414742',
#   'volume': '3456.0',
#   'surface_area': '1392.0',
#   'alpha': '53.51336095970972',
#   'beta': '63.514168891122544',
#   'gamma': '48.01278750418334',
#   'radius_described_sphere': '13.45362404707371',
#   'volume_described_sphere': '10200.14796153424'},
#  'figure_73': {'diag': '14.491376746189438',
#   'volume': '260.0',
#   'surface_area': '274.0',
#   'alpha': '26.222460373643276',
#   'beta': '73.97682027306618',
#   'gamma': '69.81620322790722',
#   'radius_described_sphere': '7.245688373094719',
#   'volume_described_sphere': '1593.4100954180742'},
#  'figure_74': {'diag': '22.02271554554524',
#   'volume': '1680.0',
#   'surface_area': '884.0',
#   'alpha': '68.6993815356869',
#   'beta': '47.069172110165034',
#   'gamma': '50.527540151656176',
#   'radius_described_sphere': '11.01135777277262',
#   'volume_described_sphere': '5592.5674440735975'},
#  'figure_75': {'diag': '27.477263328068172',
#   'volume': '3705.0',
#   'surface_area': '1454.0',
#   'alpha': '46.252558459405435',
#   'beta': '61.763087525748496',
#   'gamma': '56.91340898700094',
#   'radius_described_sphere': '13.738631664034086',
#   'volume_described_sphere': '10862.231383703243'},
#  'figure_76': {'diag': '18.275666882497067',
#   'volume': '306.0',
#   'surface_area': '342.0',
#   'alpha': '70.83404801382193',
#   'beta': '21.534203578960806',
#   'gamma': '80.55198356479771',
#   'radius_described_sphere': '9.137833441248533',
#   'volume_described_sphere': '3196.08501217456'},
#  'figure_77': {'diag': '13.416407864998739',
#   'volume': '320.0',
#   'surface_area': '304.0',
#   'alpha': '53.395723557294346',
#   'beta': '41.810314895778596',
#   'gamma': '72.65393470733007',
#   'radius_described_sphere': '6.708203932499369',
#   'volume_described_sphere': '1264.466651587331'},
#  'figure_78': {'diag': '17.378147196982766',
#   'volume': '630.0',
#   'surface_area': '482.0',
#   'alpha': '36.33084348794846',
#   'beta': '73.2786345860582',
#   'gamma': '58.80905618056901',
#   'radius_described_sphere': '8.689073598491383',
#   'volume_described_sphere': '2747.9513315411696'},
#  'figure_79': {'diag': '23.0',
#   'volume': '756.0',
#   'surface_area': '696.0',
#   'alpha': '82.50528254607332',
#   'beta': '38.499950409247866',
#   'gamma': '52.50475023544138',
#   'radius_described_sphere': '11.5',
#   'volume_described_sphere': '6370.6263027045015'},
#  'figure_80': {'diag': '23.430749027719962',
#   'volume': '544.0',
#   'surface_area': '676.0',
#   'alpha': '43.48601885688793',
#   'beta': '85.10339302523506',
#   'gamma': '46.932196695412465',
#   'radius_described_sphere': '11.715374513859981',
#   'volume_described_sphere': '6735.303014743595'},
#  'figure_81': {'diag': '18.76166303929372',
#   'volume': '1152.0',
#   'surface_area': '672.0',
#   'alpha': '50.23784084819495',
#   'beta': '50.23784084819495',
#   'gamma': '64.7605981793211',
#   'radius_described_sphere': '9.38083151964686',
#   'volume_described_sphere': '3457.9014960378413'},
#  'figure_82': {'diag': '22.15851980616034',
#   'volume': '1197.0',
#   'surface_area': '734.0',
#   'alpha': '66.0358903443722',
#   'beta': '71.5845086580629',
#   'gamma': '30.96764612510235',
#   'radius_described_sphere': '11.07925990308017',
#   'volume_described_sphere': '5696.667355231917'},
#  'figure_83': {'diag': '19.6468827043885',
#   'volume': '528.0',
#   'surface_area': '514.0',
#   'alpha': '55.95213703056569',
#   'beta': '81.21680501190248',
#   'gamma': '35.47403864973534',
#   'radius_described_sphere': '9.82344135219425',
#   'volume_described_sphere': '3970.814319139707'},
#  'figure_84': {'diag': '25.45584412271571',
#   'volume': '3136.0',
#   'surface_area': '1288.0',
#   'alpha': '56.63491197922432',
#   'beta': '51.057558731018624',
#   'gamma': '56.63491197922432',
#   'radius_described_sphere': '12.727922061357855',
#   'volume_described_sphere': '8636.964431779863'},
#  'figure_85': {'diag': '22.045407685048602',
#   'volume': '1350.0',
#   'surface_area': '810.0',
#   'alpha': '47.12401133336427',
#   'beta': '47.12401133336427',
#   'gamma': '74.20683095173604',
#   'radius_described_sphere': '11.022703842524301',
#   'volume_described_sphere': '5609.872957127992'},
#  'figure_86': {'diag': '23.0',
#   'volume': '756.0',
#   'surface_area': '696.0',
#   'alpha': '82.50528254607332',
#   'beta': '52.50475023544138',
#   'gamma': '38.499950409247866',
#   'radius_described_sphere': '11.5',
#   'volume_described_sphere': '6370.6263027045015'},
#  'figure_87': {'diag': '19.131126469708992',
#   'volume': '38.0',
#   'surface_area': '118.0',
#   'alpha': '87.0037361516869',
#   'beta': '6.71213856499447',
#   'gamma': '83.99923887073341',
#   'radius_described_sphere': '9.565563234854496',
#   'volume_described_sphere': '3666.2345887002352'},
#  'figure_88': {'diag': '22.759613353482084',
#   'volume': '510.0',
#   'surface_area': '638.0',
#   'alpha': '84.95863345422151',
#   'beta': '41.674246418500715',
#   'gamma': '48.77161284260321',
#   'radius_described_sphere': '11.379806676741042',
#   'volume_described_sphere': '6172.957144816486'},
#  'figure_89': {'diag': '18.841443681416774',
#   'volume': '945.0',
#   'surface_area': '606.0',
#   'alpha': '61.46663740771574',
#   'beta': '37.23908117204728',
#   'gamma': '68.19052187851354',
#   'radius_described_sphere': '9.420721840708387',
#   'volume_described_sphere': '3502.2016789434156'},
#  'figure_90': {'diag': '6.4031242374328485',
#   'volume': '12.0',
#   'surface_area': '40.0',
#   'alpha': '20.439317573258254',
#   'beta': '71.79923973546668',
#   'gamma': '81.01512306831432',
#   'radius_described_sphere': '3.2015621187164243',
#   'volume_described_sphere': '137.45938843966883'},
#  'figure_91': {'diag': '19.6468827043885',
#   'volume': '228.0',
#   'surface_area': '290.0',
#   'alpha': '78.25275706194178',
#   'beta': '81.21680501190248',
#   'gamma': '14.74356283647072',
#   'radius_described_sphere': '9.82344135219425',
#   'volume_described_sphere': '3970.814319139707'},
#  'figure_92': {'diag': '18.466185312619388',
#   'volume': '1008.0',
#   'surface_area': '620.0',
#   'alpha': '60.831653968581904',
#   'beta': '64.32764366268599',
#   'gamma': '40.699282209327784',
#   'radius_described_sphere': '9.233092656309694',
#   'volume_described_sphere': '3297.0853587036504'},
#  'figure_93': {'diag': '21.42428528562855',
#   'volume': '221.0',
#   'surface_area': '502.0',
#   'alpha': '87.32469000763449',
#   'beta': '52.64238231560143',
#   'gamma': '37.48694312044027',
#   'radius_described_sphere': '10.712142642814275',
#   'volume_described_sphere': '5148.937860523304'},
#  'figure_94': {'diag': '24.535688292770594',
#   'volume': '2640.0',
#   'surface_area': '1162.0',
#   'alpha': '63.36363353800428',
#   'beta': '52.3125034740189',
#   'gamma': '49.29902410264515',
#   'radius_described_sphere': '12.267844146385297',
#   'volume_described_sphere': '7733.80752183083'},
#  'figure_95': {'diag': '17.320508075688775',
#   'volume': '280.0',
#   'surface_area': '376.0',
#   'alpha': '54.735610317245346',
#   'beta': '36.07076865079636',
#   'gamma': '83.36926223192135',
#   'radius_described_sphere': '8.660254037844387',
#   'volume_described_sphere': '2720.699046351327'},
#  'figure_96': {'diag': '18.411952639521967',
#   'volume': '425.0',
#   'surface_area': '390.0',
#   'alpha': '74.24272082809752',
#   'beta': '22.584632183507953',
#   'gamma': '74.24272082809752',
#   'radius_described_sphere': '9.205976319760984',
#   'volume_described_sphere': '3268.1213160069447'},
#  'figure_97': {'diag': '21.0',
#   'volume': '608.0',
#   'surface_area': '520.0',
#   'alpha': '67.60731219459836',
#   'beta': '25.208765296758365',
#   'gamma': '79.01942457238785',
#   'radius_described_sphere': '10.5',
#   'volume_described_sphere': '4849.048260815845'},
#  'figure_98': {'diag': '22.293496809607955',
#   'volume': '1140.0',
#   'surface_area': '728.0',
#   'alpha': '31.540953594644105',
#   'beta': '63.348583884900044',
#   'gamma': '74.38709315891892',
#   'radius_described_sphere': '11.146748404803978',
#   'volume_described_sphere': '5801.4052737577085'},
#  'figure_99': {'diag': '13.038404810405298',
#   'volume': '60.0',
#   'surface_area': '154.0',
#   'alpha': '67.45043607798635',
#   'beta': '85.60129464500447',
#   'gamma': '23.021526638116182',
#   'radius_described_sphere': '6.519202405202649',
#   'volume_described_sphere': '1160.5717750621413'},
#  'figure_100': {'diag': '21.447610589527216',
#   'volume': '1080.0',
#   'surface_area': '696.0',
#   'alpha': '62.208694355220786',
#   'beta': '32.938537994038256',
#   'gamma': '73.75462941646684',
#   'radius_described_sphere': '10.723805294763608',
#   'volume_described_sphere': '5165.773616325357'}}

# %%
average_values
# Out:
# {'avg_diag': 241.94767596965377,
#  'avg_volume': 13538.25,
#  'avg_surface_area': 7846.0,
#  'avg_alpha': 708.1266903395011,
#  'avg_beta': 722.6627231945552,
#  'avg_gamma': 693.7376001779688,
#  'avg_radius_described_sphere': 120.97383798482689,
#  'avg_volume_described_sphere': 58161.67942856987}

# %%
with open("characteristics.json", "w") as outfile: 
    json.dump(result_dict, outfile, indent=2)

with open("statistics.json", "w") as outfile: 
    json.dump(average_values, outfile, indent=2)
