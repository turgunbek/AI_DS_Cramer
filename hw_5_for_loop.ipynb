# %% [markdown]
# # Task 1
# Создайте список чисел
# ```
# task1 = [1, 2, 3, 4, 5]
# ```
# Переберите элементы циклом и удалите все четные элементы

# %%
task1 = [1, 2, 3, 4, 5]
evens = [el for el in task1 if el % 2 == 0]
for el in evens:
    task1.remove(el)
print(task1)
# Out:
# [1, 3, 5]

# %% [markdown]
# # Task 2
#
#
#
# > ### Задача A
#
#
#
# Создайте список list1 цифр от 1 до n, где n вводится с клавиатуры.
#
# Полученный список должен содержать элементы в формате str
#
#
#
#
#
# Например:
# ```
# n = 5
# ['1', '2', '3', '4', '5']
# ```

# %%
n = int(input('Input digit from 1 to 9:'))
list1 = [str(d) for d in range(1, n+1)]
print(list1)
# Out:
# Input digit from 1 to 9:9
# ['1', '2', '3', '4', '5', '6', '7', '8', '9']

# %% [markdown]
# > ### Задача B
#
#
#
# Для полученного списка сделайте следущее:
#
#
# Все числа под нечетными индексами умножте на 10
#
#
#
# ```
# ['1', '20', '3', '40', '5']
# ```

# %%
list2 = ['1', '20', '3', '40', '5']
for i in range(1, len(list2), 2):
    list2[i] = str(int(list2[i]) * 10)
print(list2)
# Out:
# ['1', '200', '3', '400', '5']

# %% [markdown]
# # Task 3
#
# Дан список [1, 22, 3, 45, 22, 4, 89, 87, 87, 4], создайте новую переменную task3 и добавьте каждый
# второй элемент данного списка в эту переменную

# %%
list3 = [1, 22, 3, 45, 22, 4, 89, 87, 87, 4]
task3 = sum(list3[1::2])
print(task3)
# Out:
# 162

# %% [markdown]
# # Task 4
# В переменной ls хранится список [11, 23, 45, 7, 9], запринтите каждый элемент ls, начиная с конца

# %%
ls = [11, 23, 45, 7, 9]
for el in ls[::-1]:
    print(el)
# Out:
# 9
# 7
# 45
# 23
# 11

# %% [markdown]
# # Task 5
#
# Сгенерите список из 17-ти ID пользователей по следующему образцу:
#
#
# ```
# ['ID_0001', 'ID_0002', 'ID_0003', 'ID_0004', 'ID_0005'.....'ID_0016', 'ID_0017']
# ```
# ответ сохраните в переменной task5

# %%
task5 = [f'ID_00{id:02d}' for id in range(1, 18)]
print(task5)
# Out:
# ['ID_0001', 'ID_0002', 'ID_0003', 'ID_0004', 'ID_0005', 'ID_0006', 'ID_0007', 'ID_0008', 'ID_0009', 'ID_0010', 'ID_0011', 'ID_0012', 'ID_0013', 'ID_0014', 'ID_0015', 'ID_0016', 'ID_0017']

# %% [markdown]
# # Task 6
#
# Дан адрес. Достаньте из него Город, Улицу и номер дома. Значения сохраните в переменные:
#
#
# ```
# city
# >>> 'Бишкек'
# street
# >>> 'Осмонкулова'
# house_number
# >>> 15
# ```
# Используйте split() и цикл for

# %%
address = 'г. Бишкек, ул. Абдрахманова, д. 25'

# %%
address = address.replace('г.','')
address = address.replace('ул.','')
address = address.replace('д.','')
address = address.replace(',','')
city, street, house_number = address.split()
print(city)
print(street)
print(house_number)
# Out:
# Бишкек
# Абдрахманова
# 25

# %% [markdown]
# # Task 7
# Дан список чисел. Составьте из него список ID пользователей, добавив к каждому числу приставку 'ID_'
# ```
# users = [23, 24, 43, 25, 83]
# >>> ['ID_23', 'ID_24', 'ID_43', 'ID_25', 'ID_83']
# ```
# ответ запишите в переменную task7

# %%
users = [23, 24, 43, 25, 83]
task7 = ['ID_' + str(user) for user in users]
print(task7)
# Out:
# ['ID_23', 'ID_24', 'ID_43', 'ID_25', 'ID_83']

# %% [markdown]
# # Task 8
#
# По данной строке
# my_str = 'abcdefg12345'
# создайте список в переменной task8, который состоит из отдельных символов данной строки
# Например:
# ```
# str = 'abc'
# >>>['a', 'b', 'c']
# ```

# %%
my_str = 'abcdefg12345'
task8 = list(my_str)
print(task8)
# Out:
# ['a', 'b', 'c', 'd', 'e', 'f', 'g', '1', '2', '3', '4', '5']

# %% [markdown]
# # Task 9
#
#
# В распоряжении начальника имеется бригада рабочих в составе 24 человек. Их нужно распределить на день на два объекта. Если на первом объекте работает t человек, то их суточная зарплата составляет $4t^2$ USD. Если на втором объекте работает t человек, то их суточная зарплата составляет $t^2$ USD. Как нужно распределить на эти объекты бригаду рабочих, чтобы выплаты на их суточную зарплату оказались наименьшими? Сколько USD в этом случае придется заплатить рабочим?
#
#
#
# ---
#
#
#
# ---
#
#
#
# ---
#
#
#
#
# Для решения данной задачи за  $t$  возмем количество работников на первом объекте.
#
# Тогда на втором будет работать $(24-t)$ человек.
#
# Расчет общей стоимости оплаты труда для всех рабочих будет расчитываться следущим образом:
#
# $$s = 4t^2 + (24-t)^2$$
#
# Расчитайте минимально возможное $s$.
#
# Вам необходимо будет перебрать циклом все возможные $t$ от 1 до 24.
#
# (По сути, это задача нахождения минимума функции. Не забывайте функцию min())

# %%
task9 = min([4*t**2 + (24-t)**2 for t in range(1, 25)])
print(task9)
# Out:
# 461

# %% [markdown]
# # Task 10
#
# Из данного списка достаньте только числа. Сохраните их в виде списка в переменной task10.
#
#
# ```
# id_list = ['ID_23', 'ID_24', 'ID_43', 'ID_25', 'ID_83']
#
# >>> [23, 24, 43, 25, 83]
# ```

# %%
id_list = ['ID_23', 'ID_24', 'ID_43', 'ID_25', 'ID_83']
task10 = [int(el[3:]) for el in id_list]
print(task10)
# Out:
# [23, 24, 43, 25, 83]

# %% [markdown]
# # Task 11
#
# Дан список чисел. Напишите программу, которая возвращает новый список чисел, которые являются суммами СОСЕДНИХ ЧИСЕЛ для каждого числа данного списка.
#
# Для первого числа соседями являются последнее и второе число.
#
# Для последнего - первое и предпоследнее.
#
# Не забывайте, что list[-1] - вернет последнее число.
#
# Новый список сохраните в переменной task11
#
#
# ```
# input: [1, 3, 2, 4]
#
# output: [7, 3, 7, 3]
# ```

# %%
num_list = [2, 4, 6, 8, 6, 4, 5]

# %%
task11 = [num_list[i-1]+num_list[i+1] for i in range(len(num_list) - 1)] + [num_list[0] + num_list[-2]]
print(task11)
# Out:
# [9, 8, 12, 12, 12, 11, 6]

# %% [markdown]
# # Task 12
# С помощью цикла найдите целочисленные корни уравнения $x^2 -11x + 30=0$. Верните ответы в виде списка в переменной task12.

# %%
roots = []
for r in range(-10, 10):
    if r**2 - 11*r + 30 == 0:
        roots.append(r)
task12 = roots
print(task12)
# Out:
# [5, 6]

# %% [markdown]
# # Task 13
# Найдите минимум функции $y = x^2 - 8x + 3$ (Минимальное значение функции), ответ сохраните в переменной task13

# %%
# y' = 2x - 8 = 0 => x_min = 4
x_min = 4
task13 = x_min**2 - 8*x_min + 3
print(task13)
# Out:
# -13

# %% [markdown]
# # Task 14
# Найти значение аргумента при котором функция имеет максимум.
#
# $y = x^2 -x - 6$
#
# ответ сохраните в переменную task14

# %%
# y(x) - парабола, ветви которой направлены вверх => у неё нет максимума
task14 = 'У функции y = x^2 - x - 6 нет максимума'
print(task14)
# Out:
# У функции y = x^2 - x - 6 нет максимума

# %% [markdown]
# # Task 15
# Методом перебора найдите координату $x$ точки пересечения прямых
#
# $y = 2x-3$
#
# $y = -x + 6$

# %%
for x in range(0, 10):
    if 2*x-3 == -x + 6:
        root = x
print(f'x = {root}')
# Out:
# x = 3

# %% [markdown]
# # Task 16
# У вас есть список
#
# task16 = [1, 22, 3, 45, 22, 4, 89, 87, 87, 4], удалите из него каждый второй элемент

# %%
task16 = [1, 22, 3, 45, 22, 4, 89, 87, 87, 4]
for i in range(1, len(task16)//2 + 1):
    task16.pop(i)
print(task16)
# Out:
# [1, 3, 22, 89, 87]

# %% [markdown]
# # Task 17
# Вам дан список с числами [1, 3, '1', 4, '89', 5, '9', 7, "75", 12],
# найдите сумму чисел в этом списке не используя функцию sum(), числа могут быть в виде строки
# переведите их в int и тоже прибавьте к сумме, ответ запишите в переменную task17

# %%
some_list = [1, 3, '1', 4, '89', 5, '9', 7, "75", 12]
s = 0
for el in some_list:
    s += int(el)
task17 = s
print(s)
# Out:
# 206

# %% [markdown]
# # Task 18
# Дан список [1, 22, 3, 45, 22, 4, 89, 87, 87, 4], запринтите все элементы с конца до середины,
# используйте range

# %%
some_list = [1, 22, 3, 45, 22, 4, 89, 87, 87, 4]
n = len(some_list)
for i in range(n // 2, n):
    print(some_list[i])
# Out:
# 4
# 89
# 87
# 87
# 4

# %% [markdown]
# # Task 19
# Решите задачу оптимизации используя итерацию:
#
# ![image.png](data:image/png;base64,...)

# %%
max_p = 0
i_max_p = -1
for d in range(2, 22 + 1):
    p = d / 22 + (25-d) / 23
    print(f'Девочек в 1м классе = {d}, во 2м классе = {25-d}: сумма процентов девочек = {p*100}%')
    if p > max_p:
        max_p = p
        i_max_p = d
print(f'В 1м классе должно быть {i_max_p} девочек, во 2м классе должно быть {25-i_max_p}.')
# Out:
# Девочек в 1м классе = 2, во 2м классе = 23: сумма процентов девочек = 109.09090909090908%
# Девочек в 1м классе = 3, во 2м классе = 22: сумма процентов девочек = 109.28853754940712%
# Девочек в 1м классе = 4, во 2м классе = 21: сумма процентов девочек = 109.48616600790513%
# Девочек в 1м классе = 5, во 2м классе = 20: сумма процентов девочек = 109.68379446640316%
# Девочек в 1м классе = 6, во 2м классе = 19: сумма процентов девочек = 109.88142292490117%
# Девочек в 1м классе = 7, во 2м классе = 18: сумма процентов девочек = 110.07905138339922%
# Девочек в 1м классе = 8, во 2м классе = 17: сумма процентов девочек = 110.27667984189722%
# Девочек в 1м классе = 9, во 2м классе = 16: сумма процентов девочек = 110.47430830039526%
# Девочек в 1м классе = 10, во 2м классе = 15: сумма процентов девочек = 110.67193675889328%
# Девочек в 1м классе = 11, во 2м классе = 14: сумма процентов девочек = 110.86956521739131%
# ...

# %% [markdown]
# # Task 20
# Решите задачу методом перебора:
#
# ![image.png](data:image/png;base64,...)

# %%
s_min = 1e6
t_min = -1
for t in range(0, 24 + 1):
    s = 4*t**2 + (24-t)**2
    if s < s_min:
        s_min = s
        t_min = t
print(f'Оптимальное распределение: {t_min} рабочих на 1й объект, {24-t_min} рабочих на 2й объект.')
print(f'При этом придется заплатить {s_min} у.е.')
# Out:
# Оптимальное распределение: 5 рабочих на 1й объект, 19 рабочих на 2й объект.
# При этом придется заплатить 461 у.е.

# %% [markdown]
# # Task 21
# ![image.png](data:image/png;base64,...)

# %%
# Пусть 1й едет по оси X, а 2й по оси Y. Перекресток в точке (0, 0).
# Пусть изначальное положение 1го было в точке (-5,0), а 2го - в точке (0, -3).
# Закон движения 1го: x1(t) = -5 + 40t, y1(t) = 0.
# Закон движения 2го: x2(t) = 0, y2(t) = -3 + 30t.
# Функция квадрата расстояния от времени:
# d2(t) = (x1-x2)**2 + (y1-y2)**2 -> min
# d2(t) = 1600t^2 - 400t + 25 + 900t^2 - 180t + 9 = 2500t^2 - 580t + 34
# Найдем минимум с помощью производной: d2'(t) = 5000t - 580 = 0 =>
t_min = 580 / 5000
print(f'Искомое время = {t_min*60} минут')
print(f'При этом расстояние = {((-5+40*t_min)**2 + (-3+30*t_min)**2)**0.5:.4f} км')
# Out:
# Искомое время = 6.96 минут
# При этом расстояние = 0.6000 км
