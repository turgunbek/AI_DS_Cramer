# %% [markdown]
# # Task 1
# Объявите две переменные number1, number2 со значениями в виде целых чисел (int).
# Сложите их, ответ запишите в переменную num1

# %%
number1, number2 = -2, 3
num1 = number1 + number2
print(num1)
# Out:
# 1

# %% [markdown]
# # Task 2
# Создайте две переменные number1, number2 и присвойте им целые числа.
# Разделите первое на второе, вернув только целую часть от деления. Ответ сохраните в переменную num2.

# %%
number1, number2 = -2, 3
num2 = number1 // number2
print(num2)
# Out:
# -1

# %% [markdown]
# # Task 3
# Создать две переменные number1, number2 со значением типа int.
# Найдите остаток от деления первого на второе, ответ запишите в переменную num3

# %%
number1, number2 = -2, 3
num3 = number1 % number2
print(num3)
# Out:
# 1

# %% [markdown]
# # Task 4
# Создайте три переменные со значением типа float, присвоив им дробные числа: float_num1, float_num2, float_num3.
# Умножьте первое число на второе и поделите результат обычным делением на третье. Ответ запишите в переменную num4.

# %%
float_num1 = 1.5
float_num2 = -0.2
float_num3 = 1.0
num4 = float_num1 * float_num2 / float_num3
print(num4)
# Out:
# -0.30000000000000004

# %% [markdown]
# # Task 5
# Создайте переменную num типа float, возведите ее в куб и поделите на 2.
# Ответ округлите до десятых (одно число после точки) и запишите в переменную num5.

# %%
num = -1.5
num5 = round(num**3 / 2, 1)
print(num5)
# Out:
# -1.7

# %% [markdown]
# # Task 6
# Создайте две переменные number1, number2 типа float. Вычтите из первого числа второе. Ответ округлите в меньшую сторону и запишите в переменную num6.

# %%
from math import floor
number1, number2 = -1.5, 2.0
num6 = floor(number1 - number2)
print(num6)
# Out:
# -4

# %% [markdown]
# # Task 7
# Создайте две переменные number1, number2 типа float. Вычтите из первого числа второе.
# Ответ округлите в большую сторону, запишите в переменную num7.

# %%
from math import ceil
number1, number2 = -1.5, 2.0
num7 = ceil(number1 - number2)
print(num7)
# Out:
# -3

# %% [markdown]
# # Task 8
# В переменные a, b запишите два числа, которые будут обозначать два катета прямоугольного треугольника.
# Рассчитайте длину гипотенузы треугольника и присвойте переменной c, воспользовавшись теоремой Пифагора. (можно воспользоваться библиотекой math). Ответ запишите в переменную num8.

# %% [markdown]
# $$c = \sqrt{a^2 + b^2}$$

# %%
a, b = 3, 4
num8 = (a**2 + b**2)**0.5
print(num8)
# Out:
# 5.0

# %% [markdown]
# # Task 9
# Даны две переменные со значением типа int.
# Одно положительное pos_num, второе отрицательное neg_num.
# Вычислите сумму модулей этих чисел и ответ запишите в переменную num9.

# %%
pos_num = 5
neg_num = -7
num9 = abs(pos_num) + abs(neg_num)
print(num9)
# Out:
# 12

# %% [markdown]
# # Task 10
# Дана переменная temp с температурой воздуха по Фаренгейту(int).
# Переведите это значение в температуру по Цельсию (ответ округлите до сотых),
# ответ запишите в переменную num10.

# %%
temp = 90
num10 = round((temp - 32) * 5/9, 2)
print(num10)
# Out:
# 32.22

# %% [markdown]
# ---
#
#
#
# ---
#
#
# <h3>Решение примеров, которые пойдут ниже необходимо прописывать полностью, начиная с переписывания примеров в синтаксис питона. Смешанные числа как $2\frac{2}{3}$ вы можете перевести в дроби и записывать так:
#
#
# ```
# (2 + 2/3)
# ```
#
#
# Не забудьте что float записываются через точку.
#
# Например:
#
# test = ((5 + 5) / 2.3) - ((23.4 + 23.6) / 23)

# %% [markdown]
# # Task 11
# ![int_task1.png](data:image/png;base64,...)
#
#
# конечный ответ должен хранится в переменной num11

# %%
num11 = ((6+7/12 - (3+17/36)) * 2.5 - (4+1/3)/0.65) / (4/(1/4) - 0.5)
print(num11)
# Out:
# 0.07168458781362004

# %% [markdown]
# # Task 12
# ![int_task2.png](data:image/png;base64,...)
#
# конечный ответ должен хранится в переменной num12

# %%
num12 = ((2+3/4)/1.1 + 3+1/3) / (2.5 - 0.4*(3+1/3)) / (5/7) - (2+1/6 + 4.5)*0.375 / (2.75 - (1+1/2))
print(num12)
# Out:
# 5.0

# %% [markdown]
# # Task 13
# ![int_task3.png](data:image/png;base64,...)
#
# конечный ответ должен хранится в переменной num13

# %%
num13 = 11+2/5 + (7+1/2)*(285.6/14 - (1+23/30) + 13/50) / (24.4 - 10.23)
print(num13)
# Out:
# 21.400000000000006

# %% [markdown]
# # Task 14
#
# ![int_task4.png](data:image/png;base64,...)
#
#
# конечный ответ должен хранится в переменной num14

# %%
num14 = ((9-(5+3/8))*(4+5/12-4/(2+2/3)) + (3/10 - 0.5/4)*4/7) / (1/24 + 0.25/(13+1/3))
print(num14)
# Out:
# 176.65517241379314

# %% [markdown]
# # Task 15
#
# ![int_tsk5.png](data:image/png;base64,...)
#
# конечный ответ должен хранится в переменной num15

# %%
num15 = 5.75 / 0.025
print(num15)
# Out:
# 230.0

# %% [markdown]
# # Task 16
# ![int_task6.png](data:image/png;base64,...)
#
# конечный ответ должен хранится в переменной num16

# %%
num16 = 0.4 * (0.16*(3.2-3/40) + (2+3/11)*4.125/(3+3/4)) / ((5+1/6)*0.3 - 0.3*4.5 + 1/3*0.3)
print(num16)
# Out:
# 3.999999999999998
